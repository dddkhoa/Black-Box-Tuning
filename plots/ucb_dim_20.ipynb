# %%
import matplotlib.pyplot as plt

budget = [2000, 4000, 6000, 8000, 10000, 12000]

ucb_balance = [0.8509, 0.8509, 0.8532, 0.8532, 0.8532, 0.8521]
ucb_exploit = [0.8532, 0.8521, 0.8521, 0.8544, 0.8521, 0.8486]
ucb_explore = [0.8394, 0.8475, 0.8475, 0.8475, 0.8486, 0.8486]

plt.plot(budget, ucb_balance, label='ucb-balance', marker='o')
plt.plot(budget, ucb_exploit, label='ucb-exploit', marker='o')
plt.plot(budget, ucb_explore, label='ucb-explore', marker='o')

plt.xlabel('Budget')
plt.ylabel('Test Accuracy')
plt.title('UCB 20 Dimensions')
plt.legend()
plt.grid()

plt.show()
