# %%
import matplotlib.pyplot as plt

budget = [2000, 4000, 6000, 8000]

# Expected Improvement
ei_exploit = [83.14, 83.03, 82.45, 83.26]
ei_explore = [83.03, 83.03, 83.03, 82.68]

# Probability of Improvement
poi_exploit = [83.14, 83.03, 82.45, 82.68]
poi_explore = [83.03, 83.03, 82.24, 82.68]

plt.plot(budget, ei_exploit, label='ei-exploit', marker='o')
plt.plot(budget, ei_explore, label='ei-explore', marker='o')
plt.plot(budget, poi_exploit, label='poi-exploit', marker='o')
plt.plot(budget, poi_explore, label='poi-explore', marker='o')


plt.xlabel('Budget')
plt.ylabel('Test Accuracy')
plt.title('EI vs POI 500 Dimensions')
plt.legend()
plt.grid()

plt.show()
